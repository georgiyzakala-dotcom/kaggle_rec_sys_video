# %%
import polars as pl

# %%
train_df = pl.read_parquet("../data/prepared_train_data.parquet")
train_df.head(2)
# Out:
# shape: (2, 9)
# ┌────────────┬─────────┬────────────┬────────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ user_id    ┆ item_id ┆ date       ┆ dt         ┆ … ┆ watch_tim ┆ is_like ┆ is_favori ┆ is_positi │
# │ ---        ┆ ---     ┆ ---        ┆ ---        ┆   ┆ e         ┆ ---     ┆ te        ┆ ve        │
# │ u64        ┆ i32     ┆ date       ┆ datetime[μ ┆   ┆ ---       ┆ i32     ┆ ---       ┆ ---       │
# │            ┆         ┆            ┆ s]         ┆   ┆ i64       ┆         ┆ i32       ┆ i32       │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ 6617804886 ┆ 17899   ┆ 2024-11-29 ┆ 2024-11-29 ┆ … ┆ 11        ┆ 0       ┆ 0         ┆ 0         │
# │ 732240288  ┆         ┆            ┆ 18:12:46   ┆   ┆           ┆         ┆           ┆           │
# │ 1829805440 ┆ 524994  ┆ 2024-12-01 ┆ 2024-12-01 ┆ … ┆ 30        ┆ 0       ┆ 0         ┆ 0         │
# ...
